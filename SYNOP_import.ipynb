# %% [markdown]
# ### ARIF SYNOP_Dataset Import

# %% [markdown]
# Library import

# %%
import requests
from datetime import datetime
from bs4 import BeautifulSoup
import numpy as np
import re
import json
import pandas as pd
import time
from pandas.io.json import json_normalize
import seaborn as sns
import matplotlib.pyplot as plt
import urllib.error

# %%
SYNOP_url = 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records'

SYNOP_StartDate='2021/01/01'
SYNOP_EndDate='2023/05/01'
SYNOP_json = r'C://Users/romai/Documents/Source/DAFT_0410/FinalProject/Original_Data/donnees-synop-essentielles-omm.json'

# %% [markdown]
# ### Read dataset informations & columns

# %%
# Open the JSON file
with open(SYNOP_json, 'r') as file:
    # Load the contents of the file
    json_data = json.load(file)

fields = json_data['dataset']['fields']

# Create a dataframe from the fields list
df_columns = pd.DataFrame(fields, columns=['name', 'description', 'label', 'type'])

# %%
display(df_columns)
# Out:
#                name description                              label      type
# 0         numer_sta        None                     ID OMM station      text
# 1              date        None                               Date  datetime
# 2              pmer          Pa             Pression au niveau mer       int
# 3              tend          Pa  Variation de pression en 3 heures    double
# 4          cod_tend        None      Type de tendance barométrique      text
# ..              ...         ...                                ...       ...
# 77         nom_dept        None                  department (name)      text
# 78         code_dep        None                  department (code)      text
# 79          nom_reg        None                      region (name)      text
# 80         code_reg        None                      region (code)      text
# 81  mois_de_l_annee        None                    mois_de_l_annee       int
#
# [82 rows x 4 columns]

# %%
df_columns.to_excel('donnees-synop-essentielles-omm_columns.xlsx')

# %%
# Out:
#          ID OMM station                       Date  Pression au niveau mer  \
# 1399745           78890  2022-04-21T05:00:00+02:00                101560.0
# 1399746            7168  2022-04-21T08:00:00+02:00                100930.0
# 1399747            7190  2022-04-21T08:00:00+02:00                101050.0
# 1399748            7627  2022-04-21T08:00:00+02:00                100930.0
# 1399749           61976  2022-04-21T11:00:00+02:00                101200.0
# ...                 ...                        ...                     ...
# 2247953            7471  2023-04-25T23:00:00+02:00                     NaN
# 2247954            7747  2023-04-25T23:00:00+02:00                101570.0
# 2247955           78925  2023-04-25T23:00:00+02:00                101260.0
# 2247956           81408  2023-04-25T23:00:00+02:00                101020.0
# 2247957            7481  2023-04-26T02:00:00+02:00                101760.0
#
#          Variation de pression en 3 heures  Type de tendance barométrique  \
# 1399745                               60.0                            0.0
# 1399746                                0.0                            5.0
# 1399747                              -20.0                            8.0
# 1399748                              -30.0                            5.0
# 1399749                              110.0                            8.0
# ...                                    ...                            ...
# 2247953                              130.0                            1.0
# 2247954                              150.0                            3.0
# 2247955                              -70.0                            6.0
# 2247956                               80.0                            2.0
# 2247957                               50.0                            3.0
#
#          Direction du vent moyen 10 mn  Vitesse du vent moyen 10 mn  \
# 1399745                           60.0                          9.4
# 1399746                          330.0                          1.7
# 1399747                           10.0                          2.7
# 1399748                           70.0                          0.6
# 1399749                            NaN                          NaN
# ...                                ...                          ...
# 2247953                          360.0                          2.1
# 2247954                          340.0                          3.3
# 2247955                          110.0                          2.1
# 2247956                            0.0                          0.0
# 2247957                          270.0                          1.5
#
#          Température  Point de rosée  Humidité  ...  Altitude  \
# 1399745       298.55          292.95      71.0  ...        27
# 1399746       278.85          274.95      76.0  ...       112
# 1399747       281.85          275.85      66.0  ...       150
# 1399748       280.85          280.55      98.0  ...       414
# 1399749       303.85          299.35      77.0  ...         7
# ...              ...             ...       ...  ...       ...
# 2247953       280.15          275.45      72.0  ...       833
# 2247954       288.95          284.15      73.0  ...        42
# 2247955       300.75          296.35      77.0  ...         3
# 2247956       297.75          297.05      96.0  ...         6
# 2247957       281.05          275.55      68.0  ...       235
#
#                        communes (name)  communes (code)  \
# 1399745                    La Désirade            97110
# 1399746         Barberey-Saint-Sulpice            10030
# 1399747                      Holtzheim            67212
# 1399748               Lorp-Sentaraille            09289
# 1399749  les Éparses de l'océan Indien            98415
# ...                                ...              ...
# 2247953                      Chaspuzac            43062
# 2247954                      Perpignan            66136
# 2247955                    Le Lamentin            97213
# 2247956                  Saint-Georges            97308
# 2247957             Colombier-Saugnieu            69299
#
#                                  EPCI (name)  EPCI (code)  \
# 1399745              CA La Riviera du Levant  200041507.0
# 1399746        CA Troyes Champagne Métropole  200069250.0
# 1399747          Eurométropole de Strasbourg  246700488.0
# 1399748                CC Couserans-Pyrénées  200067940.0
# 1399749                                  NaN          NaN
# ...                                      ...          ...
# 2247953                   CA du Puy-en-Velay  200073419.0
# 2247954  CU Perpignan Méditerranée Métropole  200027183.0
# 2247955        CA du Centre de la Martinique  249720061.0
# 2247956                 CC de l'Est Guyanais  249730052.0
# 2247957          CC de l'Est Lyonnais (CCEL)  246900575.0
#
#                                    department (name)  department (code)  \
# 1399745                                   Guadeloupe                971
# 1399746                                         Aube                 10
# 1399747                                     Bas-Rhin                 67
# 1399748                                       Ariège                 09
# 1399749  Terres australes et antarctiques françaises                984
# ...                                              ...                ...
# 2247953                                  Haute-Loire                 43
# 2247954                          Pyrénées-Orientales                 66
# 2247955                                   Martinique                972
# 2247956                                       Guyane                973
# 2247957                                        Rhône                 69
#
#                                        region (name)  region (code)  \
# 1399745                                   Guadeloupe            1.0
# 1399746                                    Grand Est           44.0
# 1399747                                    Grand Est           44.0
# 1399748                                    Occitanie           76.0
# 1399749  Terres australes et antarctiques françaises          984.0
# ...                                              ...            ...
# 2247953                         Auvergne-Rhône-Alpes           84.0
# 2247954                                    Occitanie           76.0
# 2247955                                   Martinique            2.0
# 2247956                                       Guyane            3.0
# 2247957                         Auvergne-Rhône-Alpes           84.0
#
#          mois_de_l_annee
# 1399745                4
# 1399746                4
# 1399747                4
# 1399748                4
# 1399749                4
# ...                  ...
# 2247953                4
# 2247954                4
# 2247955                4
# 2247956                4
# 2247957                4
#
# [228628 rows x 82 columns]

# %%
df.columns
# Out:
# Index(['ID OMM station', 'Date', 'Pression au niveau mer',
#        'Variation de pression en 3 heures', 'Type de tendance barométrique',
#        'Direction du vent moyen 10 mn', 'Vitesse du vent moyen 10 mn',
#        'Température', 'Point de rosée', 'Humidité', 'Visibilité horizontale',
#        'Temps présent', 'Temps passé 1', 'Temps passé 2', 'Nebulosité totale',
#        'Nébulosité  des nuages de l' étage inférieur',
#        'Hauteur de la base des nuages de l'étage inférieur',
#        'Type des nuages de l'étage inférieur',
#        'Type des nuages de l'étage moyen',
#        'Type des nuages de l'étage supérieur', 'Pression station',
#        'Niveau barométrique', 'Géopotentiel',
#        'Variation de pression en 24 heures',
#        'Température minimale sur 12 heures',
#        'Température minimale sur 24 heures',
#        'Température maximale sur 12 heures',
#        'Température maximale sur 24 heures',
#        'Température minimale du sol sur 12 heures',
#        'Méthode de mesure Température du thermomètre mouillé',
#        'Température du thermomètre mouillé',
#        'Rafale sur les 10 dernières minutes', 'Rafales sur une période',
#        'Periode de mesure de la rafale', 'Etat du sol',
#        'Hauteur totale de la couche de neige, glace, autre au sol',
#        'Hauteur de la neige fraîche', 'Periode de mesure de la neige fraiche',
#        'Précipitations dans la dernière heure',
#        'Précipitations dans les 3 dernières heures',
#        'Précipitations dans les 6 dernières heures',
#        'Précipitations dans les 12 dernières heures',
#        'Précipitations dans les 24 dernières heures', 'Phénomène spécial 1',
#        'Phénomène spécial 2', 'Phénomène spécial 3', 'Phénomène spécial 4',
#        'Nébulosité couche nuageuse 1', 'Type nuage 1', 'Hauteur de base 1',
#        'Nébulosité couche nuageuse 2', 'Type nuage 2', 'Hauteur de base 2',
#        'Nébulosité couche nuageuse 3', 'Type nuage 3', 'Hauteur de base 3',
#        'Nébulosité couche nuageuse 4', 'Type nuage 4', 'Hauteur de base 4',
#        'Coordonnees', 'Nom', 'Type de tendance barométrique.1',
#        'Temps passé 1.1', 'Temps présent.1', 'Température (°C)',
#        'Température minimale sur 12 heures (°C)',
#        'Température minimale sur 24 heures (°C)',
#        'Température maximale sur 12 heures (°C)',
#        'Température maximale sur 24 heures (°C)',
#        'Température minimale du sol sur 12 heures (en °C)', 'Latitude',
#        'Longitude', 'Altitude', 'communes (name)', 'communes (code)',
#        'EPCI (name)', 'EPCI (code)', 'department (name)', 'department (code)',
#        'region (name)', 'region (code)', 'mois_de_l_annee'],
#       dtype='object')

# %%
df_grouped = df.groupby(['region (name)','Date']).agg({'Pression au niveau mer': 'mean',
                                                       'Direction du vent moyen 10 mn': 'mean',
                                                       'Vitesse du vent moyen 10 mn' : 'mean',
                                                       'Température' : 'mean',
                                                       'Humidité' : 'mean',
                                                       'Pression station' : 'mean',
                                                       'Précipitations dans la dernière heure' : 'mean',
                                                       'Température (°C)' : 'mean'
                                                       })
df_grouped.reset_index(drop=False, inplace=True)

# %%
#Date manipulation

df_grouped['DateD'] = pd.to_datetime(df_grouped['Date'].str[:10])
df_grouped = df_grouped[df_grouped['DateD'] > "2021/01/01"]
df_grouped['Week'] = df_grouped['DateD'].apply(lambda x: datetime.strftime(x, '%W'))
df_grouped['Week'] = df_grouped['Week'].astype(int) + 1
df_grouped['Week']= df_grouped['Week'].apply(lambda x: str(x).zfill(2))
df_grouped['WeekN'] = df_grouped['Date'].apply(lambda x: x[:4]) 
df_grouped['WeekN']  =df_grouped['WeekN']   + df_grouped['Week']

# %%
df_grouped.drop(columns='DateD',inplace=True)
df_grouped.drop(columns='Week',inplace=True)
df_grouped.drop(columns='Date',inplace=True)

# %%
df_grouped.rename(columns={'region (name)' : 'region',
                            'Pression au niveau mer': 'pmer',
                            'Direction du vent moyen 10 mn': 'dirv',
                            'Vitesse du vent moyen 10 mn' : 'vitv',
                            'Température' : 'temp',
                            'Humidité' : 'hum',
                            'Pression station' : 'pst',
                            'Précipitations dans la dernière heure' : 'r1',
                            'Température (°C)' : 'tempc',
                            'WeekN' : 'week'
                            }
                    , inplace=True)

# %%
df_grouped.value_counts('region')
# Out:
# region
# Auvergne-Rhône-Alpes                           6746
# Normandie                                      6746
# Bretagne                                       6746
# Centre-Val de Loire                            6746
# Grand Est                                      6746
# Provence-Alpes-Côte d'Azur                     6746
# Occitanie                                      6746
# Nouvelle-Aquitaine                             6746
# Corse                                          6745
# Guyane                                         6745
# Hauts-de-France                                6744
# Pays de la Loire                               6744
# Île-de-France                                  6743
# Terres australes et antarctiques françaises    6740
# Guadeloupe                                     6739
# Saint-Pierre-et-Miquelon                       6731
# Martinique                                     6731
# Bourgogne-Franche-Comté                        6730
# La Réunion                                     6709
# Saint-Barthélemy                               6586
# Mayotte                                        4273
# dtype: int64

# %%
df_grouped
# Out:
#                       region           pmer   dirv   vitv     temp    hum  \
# 32134   Auvergne-Rhône-Alpes  101020.000000  182.5  4.600  273.525  80.25
# 32135   Auvergne-Rhône-Alpes  100986.666667  177.5  4.400  273.300  79.50
# 32136   Auvergne-Rhône-Alpes  100960.000000  267.5  6.100  273.100  82.50
# 32137   Auvergne-Rhône-Alpes  101000.000000  267.5  6.325  273.475  82.25
# 32138   Auvergne-Rhône-Alpes  100970.000000  267.5  6.775  273.900  79.50
# ...                      ...            ...    ...    ...      ...    ...
# 728113         Île-de-France  101750.000000   10.0  2.800  283.450  67.00
# 728114         Île-de-France  101810.000000   40.0  2.000  284.250  61.00
# 728115         Île-de-France  101780.000000   70.0  2.600  283.950  55.00
# 728116         Île-de-France  101900.000000   70.0  1.200  279.950  76.00
# 728117         Île-de-France  101940.000000   50.0  1.200  278.950  84.00
#
#              pst     r1   tempc    week
# 32134    96565.0  0.000   0.375  202101
# 32135    96537.5  0.000   0.150  202101
# 32136    96507.5  0.000  -0.050  202101
# 32137    96542.5  0.000   0.325  202101
# 32138    96527.5 -0.025   0.750  202101
# ...          ...    ...     ...     ...
# 728113  100660.0  0.000  10.300  202318
# 728114  100720.0  0.000  11.100  202318
# 728115  100690.0  0.000  10.800  202318
# 728116  100790.0  0.000   6.800  202318
# 728117  100830.0  0.000   5.800  202318
#
# [138928 rows x 10 columns]

# %%
df_grouped_w = df_grouped.groupby(['region','week']).agg({
                                                        'pmer': 'mean',
                                                        'dirv': 'mean',
                                                        'vitv': 'mean',
                                                        'temp': 'mean',
                                                        'hum': 'mean',
                                                        'pst': 'mean',
                                                        'r1': 'mean',
                                                        'tempc': 'mean'
                                                    })

# %%
df_grouped_w.reset_index(drop=False,inplace=True)

# %%
# Out:
#                     region    week           pmer        dirv      vitv  \
# 0     Auvergne-Rhône-Alpes  202101  101090.625000  214.531250  4.970313
# 1     Auvergne-Rhône-Alpes  202102  101548.750000  174.419643  2.805804
# 2     Auvergne-Rhône-Alpes  202103  102399.315476  189.613095  3.964732
# 3     Auvergne-Rhône-Alpes  202104  101038.095238  168.839286  4.477679
# 4     Auvergne-Rhône-Alpes  202105  101207.380952  181.964286  2.938095
# ...                    ...     ...            ...         ...       ...
# 2599         Île-de-France  202314  101507.500000  237.500000  5.517857
# 2600         Île-de-France  202315  102261.785714  140.178571  3.467857
# 2601         Île-de-France  202316  101292.321429  213.750000  4.733929
# 2602         Île-de-France  202317  101505.357143   90.714286  3.982143
# 2603         Île-de-France  202318  101409.411765  185.882353  3.529412
#
#             temp        hum            pst        r1      tempc
# 0     273.459375  80.593750   96639.375000 -0.009896   0.309375
# 1     272.501786  81.656250   97056.651786  0.018006  -0.648214
# 2     275.685268  80.858631   97888.616071  0.086607   2.535268
# 3     278.584375  75.125000   96666.517857  0.081994   5.434375
# 4     279.288690  76.127976   96836.443452  0.093452   6.138690
# ...          ...        ...            ...       ...        ...
# 2599  283.914286  68.589286  100419.285714 -0.003571  10.764286
# 2600  282.376786  62.714286  101158.928571 -0.001786   9.226786
# 2601  282.910714  75.339286  100203.214286  0.128571   9.760714
# 2602  283.755357  70.535714  100417.321429  0.080357  10.605357
# 2603  282.385294  77.117647  100315.882353  0.111765   9.235294
#
# [2604 rows x 10 columns]

# %% [markdown]
# ### Create SQL connexion to lcalhost

# %%
from sqlalchemy import create_engine
SQLengine = create_engine('mysql+mysqlconnector://anonymous:anonymous@localhost:3306/arif')

# %% [markdown]
# ### Step 1: import .csv

# %%
df= pd.read_csv(r'C:\Users\romai\Documents\Source\DAFT_0410\FinalProject\Original_Data\donnees-synop-essentielles-omm.csv',sep=';')

# %% [markdown]
# ### Step 2: group by (region,date)
# Step 3: 8 Columns selection

# %%
df_grouped = df.groupby(['region (name)','Date']).agg({'Pression au niveau mer': 'mean',
                                                       'Direction du vent moyen 10 mn': 'mean',
                                                       'Vitesse du vent moyen 10 mn' : 'mean',
                                                       'Température' : 'mean',
                                                       'Humidité' : 'mean',
                                                       'Pression station' : 'mean',
                                                       'Précipitations dans la dernière heure' : 'mean',
                                                       'Température (°C)' : 'mean'
                                                       })
df_grouped.reset_index(drop=False, inplace=True)

# %% [markdown]
# ### Step 4: filter by date

# %%
#Date manipulation

df_grouped['DateD'] = pd.to_datetime(df_grouped['Date'].str[:10])
df_grouped = df_grouped[df_grouped['DateD'] > "2021/01/01"]
df_grouped['Week'] = df_grouped['DateD'].apply(lambda x: datetime.strftime(x, '%W'))
df_grouped['Week'] = df_grouped['Week'].astype(int) + 1
df_grouped['Week']= df_grouped['Week'].apply(lambda x: str(x).zfill(2))
df_grouped['WeekN'] = df_grouped['Date'].apply(lambda x: x[:4]) 
df_grouped['WeekN']  =df_grouped['WeekN']   + df_grouped['Week']

# %%
df_grouped.drop(columns='DateD',inplace=True)
df_grouped.drop(columns='Week',inplace=True)
df_grouped.drop(columns='Date',inplace=True)

# %%
df_grouped.rename(columns={'region (name)' : 'region',
                            'Pression au niveau mer': 'pmer',
                            'Direction du vent moyen 10 mn': 'dirv',
                            'Vitesse du vent moyen 10 mn' : 'vitv',
                            'Température' : 'temp',
                            'Humidité' : 'hum',
                            'Pression station' : 'pst',
                            'Précipitations dans la dernière heure' : 'r1',
                            'Température (°C)' : 'tempc',
                            'WeekN' : 'week'
                            }
                    , inplace=True)

# %%
df_grouped_w = df_grouped.groupby(['region','week']).agg({
                                                        'pmer': 'mean',
                                                        'dirv': 'mean',
                                                        'vitv': 'mean',
                                                        'temp': 'mean',
                                                        'hum': 'mean',
                                                        'pst': 'mean',
                                                        'r1': 'mean',
                                                        'tempc': 'mean'
                                                    })

# %%
df_grouped_w.reset_index(drop=False,inplace=True)

# %% [markdown]
# ### Step 5 : save to sql synop

# %%
df_grouped_w.to_sql('synop', SQLengine, if_exists='append', index=False)
# Out:
# 2604

# %% [markdown]
# ### API

# %% [markdown]
# API ODS Opendatasoft Explore API v2
# Swagger     https://public.opendatasoft.com/api/v2/console

# %%
params = {
    'where': 'date >= "2021/01/01" AND date < "2023/02/01"',
    'limit': 100,
    'offset': 0,
    'timezone': 'UTC'
}
headers = {
    'accept': 'application/json; charset=utf-8'
}

response = requests.get(SYNOP_url, params=params, headers=headers)

if response.status_code == 200:
    data = response.json()
    # Process the data as needed
else:
    print('Error:', response.status_code)
data
# Out:
# {'total_count': 360709,
#  'links': [{'rel': 'self',
#    'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records?where=date+%3E%3D+%222021%2F01%2F01%22+AND+date+%3C+%222023%2F02%2F01%22&limit=100&offset=0&timezone=UTC&include_app_metas=False&include_links=False'},
#   {'rel': 'first',
#    'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records?where=date+%3E%3D+%222021%2F01%2F01%22+AND+date+%3C+%222023%2F02%2F01%22&limit=100&offset=0&timezone=UTC&include_app_metas=False&include_links=False'},
#   {'rel': 'last',
#    'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records?where=date+%3E%3D+%222021%2F01%2F01%22+AND+date+%3C+%222023%2F02%2F01%22&limit=100&offset=360700&timezone=UTC&include_app_metas=False&include_links=False'},
#   {'rel': 'next',
#    'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records?where=date+%3E%3D+%222021%2F01%2F01%22+AND+date+%3C+%222023%2F02%2F01%22&limit=100&offset=100&timezone=UTC&include_app_metas=False&include_links=False'}],
#  'records': [{'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/a970182c02ae2beb7e7f014ba23e38bae2a5d0d1'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'a970182c02ae2beb7e7f014ba23e38bae2a5d0d1',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 320,
#     'fields': {'numer_sta': '81415',
#      'date': '2022-06-23T00:00:00+00:00',
#      'pmer': None,
#      'tend': None,
#      'cod_tend': None,
#      'dd': 320,
#      'ff': 0.6,
#      't': 297.35,
#      'td': 296.45,
#      'u': 95,
#      'vv': None,
#      'ww': None,
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': None,
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': None,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': None,
#      'tn12': None,
#      'tn24': 295.65,
#      'tx12': None,
#      'tx24': 304.35,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': None,
#      'rafper': None,
#      'per': None,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 1.0,
#      'rr3': 1.2,
#      'rr6': 3.2,
#      'rr12': 6.2,
#      'rr24': 6.6,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': -54.028333, 'lat': 3.640167},
#      'nom': 'MARIPASOULA',
#      'type_de_tendance_barometrique': None,
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': 24.200000000000045,
#      'tn12c': None,
#      'tn24c': 22.5,
#      'tx12c': None,
#      'tx24c': 31.200000000000045,
#      'tminsolc': None,
#      'latitude': 3.640167,
#      'longitude': -54.028333,
#      'altitude': 106,
#      'libgeo': 'Maripasoula',
#      'codegeo': '97353',
#      'nom_epci': "CC de l'Ouest Guyanais",
#      'code_epci': '249730037',
#      'nom_dept': 'Guyane',
#      'code_dep': '973',
#      'nom_reg': 'Guyane',
#      'code_reg': '03',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/a1b36a7a993c98b21fefb873f13e637b32e695a1'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'a1b36a7a993c98b21fefb873f13e637b32e695a1',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 443,
#     'fields': {'numer_sta': '81401',
#      'date': '2022-06-23T03:00:00+00:00',
#      'pmer': 101320,
#      'tend': 100.0,
#      'cod_tend': '1',
#      'dd': 0,
#      'ff': 0.0,
#      't': 296.95,
#      'td': 296.65,
#      'u': 98,
#      'vv': None,
#      'ww': None,
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': None,
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 101260.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': -20.0,
#      'tn12': None,
#      'tn24': 296.75,
#      'tx12': None,
#      'tx24': 304.75,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': None,
#      'rafper': None,
#      'per': None,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 0.6,
#      'rr24': 0.6,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': -54.031667, 'lat': 5.4855},
#      'nom': 'SAINT LAURENT',
#      'type_de_tendance_barometrique': 'En hausse, puis stationnaire, ou en hausse, puis en hausse plus lente',
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': 23.80000000000001,
#      'tn12c': None,
#      'tn24c': 23.600000000000023,
#      'tx12c': None,
#      'tx24c': 31.600000000000023,
#      'tminsolc': None,
#      'latitude': 5.4855,
#      'longitude': -54.031667,
#      'altitude': 5,
#      'libgeo': 'Saint-Laurent-du-Maroni',
#      'codegeo': '97311',
#      'nom_epci': "CC de l'Ouest Guyanais",
#      'code_epci': '249730037',
#      'nom_dept': 'Guyane',
#      'code_dep': '973',
#      'nom_reg': 'Guyane',
#      'code_reg': '03',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/7b308ca91b639183173a50eeed649b30e77ef242'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '7b308ca91b639183173a50eeed649b30e77ef242',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 421,
#     'fields': {'numer_sta': '81408',
#      'date': '2022-06-23T03:00:00+00:00',
#      'pmer': 101280,
#      'tend': 40.0,
#      'cod_tend': '1',
#      'dd': 0,
#      'ff': 0.0,
#      't': 296.75,
#      'td': 296.55,
#      'u': 99,
#      'vv': None,
#      'ww': None,
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': None,
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 101200.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': -60.0,
#      'tn12': None,
#      'tn24': 296.05,
#      'tx12': None,
#      'tx24': 305.15,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': None,
#      'rafper': None,
#      'per': None,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 1.6,
#      'rr24': 1.8,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': -51.804667, 'lat': 3.890667},
#      'nom': 'SAINT GEORGES',
#      'type_de_tendance_barometrique': 'En hausse, puis stationnaire, ou en hausse, puis en hausse plus lente',
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': 23.600000000000023,
#      'tn12c': None,
#      'tn24c': 22.900000000000034,
#      'tx12c': None,
#      'tx24c': 32.0,
#      'tminsolc': None,
#      'latitude': 3.890667,
#      'longitude': -51.804667,
#      'altitude': 6,
#      'libgeo': 'Saint-Georges',
#      'codegeo': '97308',
#      'nom_epci': "CC de l'Est Guyanais",
#      'code_epci': '249730052',
#      'nom_dept': 'Guyane',
#      'code_dep': '973',
#      'nom_reg': 'Guyane',
#      'code_reg': '03',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/43aea2ced1e8624d9f083bd42a4dde69e2314db9'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '43aea2ced1e8624d9f083bd42a4dde69e2314db9',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 637,
#     'fields': {'numer_sta': '07015',
#      'date': '2022-06-23T06:00:00+00:00',
#      'pmer': 101060,
#      'tend': 70.0,
#      'cod_tend': '3',
#      'dd': 140,
#      'ff': 3.9,
#      't': 292.45,
#      'td': 288.55,
#      'u': 78,
#      'vv': 19440.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': '0',
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 100510.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': -200.0,
#      'tn12': 289.75,
#      'tn24': None,
#      'tx12': 299.25,
#      'tx24': None,
#      'tminsol': 287.45,
#      'sw': None,
#      'tw': None,
#      'raf10': 6.0,
#      'rafper': 6.0,
#      'per': -10.0,
#      'etat_sol': '0',
#      'ht_neige': 0.0,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': -0.1,
#      'rr12': -0.1,
#      'rr24': -0.1,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 3.0975, 'lat': 50.57},
#      'nom': 'LILLE-LESQUIN',
#      'type_de_tendance_barometrique': 'En baisse ou stationnaire, puis en hausse, ou en hausse, puis en hausse plus rapide',
#      'temps_passe_1': None,
#      'temps_present': 'On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution',
#      'tc': 19.30000000000001,
#      'tn12c': 16.600000000000023,
#      'tn24c': None,
#      'tx12c': 26.100000000000023,
#      'tx24c': None,
#      'tminsolc': 14.300000000000011,
#      'latitude': 50.57,
#      'longitude': 3.0975,
#      'altitude': 47,
#      'libgeo': 'Fretin',
#      'codegeo': '59256',
#      'nom_epci': 'Métropole Européenne de Lille',
#      'code_epci': '200093201',
#      'nom_dept': 'Nord',
#      'code_dep': '59',
#      'nom_reg': 'Hauts-de-France',
#      'code_reg': '32',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/c04ebe7854726aaee65d36e66c97fb99d33662b4'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'c04ebe7854726aaee65d36e66c97fb99d33662b4',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 542,
#     'fields': {'numer_sta': '07037',
#      'date': '2022-06-23T09:00:00+00:00',
#      'pmer': 101040,
#      'tend': 40.0,
#      'cod_tend': '2',
#      'dd': 200,
#      'ff': 3.8,
#      't': 292.55,
#      'td': 289.35,
#      'u': 82,
#      'vv': 48730.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
#      'n': 100.0,
#      'nbas': '8',
#      'hbas': 450.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 99220.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': -50.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': 289.85,
#      'sw': None,
#      'tw': None,
#      'raf10': 7.2,
#      'rafper': 8.5,
#      'per': -10.0,
#      'etat_sol': None,
#      'ht_neige': 0.0,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 0.0,
#      'rr24': 0.0,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 2.0,
#      'ctype1': None,
#      'hnuage1': 300.0,
#      'nnuage2': 5.0,
#      'ctype2': None,
#      'hnuage2': 480.0,
#      'nnuage3': 8.0,
#      'ctype3': None,
#      'hnuage3': 870.0,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 1.181667, 'lat': 49.383},
#      'nom': 'ROUEN-BOOS',
#      'type_de_tendance_barometrique': 'En hausse',
#      'temps_passe_1': None,
#      'temps_present': 'On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution',
#      'tc': 19.400000000000034,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': 16.700000000000045,
#      'latitude': 49.383,
#      'longitude': 1.181667,
#      'altitude': 151,
#      'libgeo': 'Boos',
#      'codegeo': '76116',
#      'nom_epci': 'Métropole Rouen Normandie',
#      'code_epci': '200023414',
#      'nom_dept': 'Seine-Maritime',
#      'code_dep': '76',
#      'nom_reg': 'Normandie',
#      'code_reg': '28',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/d151d5914ea510bffc5ee863691b5b786bcf3885'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'd151d5914ea510bffc5ee863691b5b786bcf3885',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 604,
#     'fields': {'numer_sta': '07168',
#      'date': '2022-06-23T09:00:00+00:00',
#      'pmer': 101200,
#      'tend': -30.0,
#      'cod_tend': '8',
#      'dd': 170,
#      'ff': 2.9,
#      't': 296.85,
#      'td': 289.15,
#      'u': 62,
#      'vv': 19870.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': '5',
#      'hbas': 3660.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 99850.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 150.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': 290.55,
#      'sw': None,
#      'tw': None,
#      'raf10': 5.0,
#      'rafper': 6.0,
#      'per': -10.0,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 0.0,
#      'rr24': 4.6,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 5.0,
#      'ctype1': None,
#      'hnuage1': 3660.0,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 4.02, 'lat': 48.324667},
#      'nom': 'TROYES-BARBEREY',
#      'type_de_tendance_barometrique': 'Stationnaire ou en hausse, puis en baisse, ou en baisse, puis en baisse plus rapide',
#      'temps_passe_1': None,
#      'temps_present': 'On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution',
#      'tc': 23.700000000000045,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': 17.400000000000034,
#      'latitude': 48.324667,
#      'longitude': 4.02,
#      'altitude': 112,
#      'libgeo': 'Barberey-Saint-Sulpice',
#      'codegeo': '10030',
#      'nom_epci': 'CA Troyes Champagne Métropole',
#      'code_epci': '200069250',
#      'nom_dept': 'Aube',
#      'code_dep': '10',
#      'nom_reg': 'Grand Est',
#      'code_reg': '44',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/97849bae1033afe2973ff31c3274509e4a7e101f'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '97849bae1033afe2973ff31c3274509e4a7e101f',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 434,
#     'fields': {'numer_sta': '81408',
#      'date': '2022-06-23T09:00:00+00:00',
#      'pmer': 101190,
#      'tend': 80.0,
#      'cod_tend': '3',
#      'dd': 0,
#      'ff': 0.0,
#      't': 295.05,
#      'td': 294.85,
#      'u': 99,
#      'vv': None,
#      'ww': None,
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': None,
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 101110.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': -10.0,
#      'tn12': None,
#      'tn24': 294.95,
#      'tx12': None,
#      'tx24': 305.15,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': None,
#      'rafper': None,
#      'per': None,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 0.0,
#      'rr24': 1.6,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': -51.804667, 'lat': 3.890667},
#      'nom': 'SAINT GEORGES',
#      'type_de_tendance_barometrique': 'En baisse ou stationnaire, puis en hausse, ou en hausse, puis en hausse plus rapide',
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': 21.900000000000034,
#      'tn12c': None,
#      'tn24c': 21.80000000000001,
#      'tx12c': None,
#      'tx24c': 32.0,
#      'tminsolc': None,
#      'latitude': 3.890667,
#      'longitude': -51.804667,
#      'altitude': 6,
#      'libgeo': 'Saint-Georges',
#      'codegeo': '97308',
#      'nom_epci': "CC de l'Est Guyanais",
#      'code_epci': '249730052',
#      'nom_dept': 'Guyane',
#      'code_dep': '973',
#      'nom_reg': 'Guyane',
#      'code_reg': '03',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/51bbcc85d568efc70d8ec09f9fa39b28cf4c0e1b'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '51bbcc85d568efc70d8ec09f9fa39b28cf4c0e1b',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 659,
#     'fields': {'numer_sta': '07460',
#      'date': '2022-06-23T12:00:00+00:00',
#      'pmer': 100760,
#      'tend': -210.0,
#      'cod_tend': '8',
#      'dd': 90,
#      'ff': 3.4,
#      't': 299.45,
#      'td': 290.25,
#      'u': 57,
#      'vv': 19500.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': '5',
#      'hbas': 1250.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 97070.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 0.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': 290.85,
#      'sw': None,
#      'tw': None,
#      'raf10': 6.8,
#      'rafper': 7.8,
#      'per': -10.0,
#      'etat_sol': '0',
#      'ht_neige': 0.0,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 4.1,
#      'rr24': 4.1,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 1.0,
#      'ctype1': None,
#      'hnuage1': 1110.0,
#      'nnuage2': 5.0,
#      'ctype2': None,
#      'hnuage2': 1320.0,
#      'nnuage3': 5.0,
#      'ctype3': None,
#      'hnuage3': 1860.0,
#      'nnuage4': None,
#      'ctype4': '9',
#      'hnuage4': None,
#      'coordonnees': {'lon': 3.149333, 'lat': 45.786833},
#      'nom': 'CLERMONT-FD',
#      'type_de_tendance_barometrique': 'Stationnaire ou en hausse, puis en baisse, ou en baisse, puis en baisse plus rapide',
#      'temps_passe_1': None,
#      'temps_present': 'On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution',
#      'tc': 26.30000000000001,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': 17.700000000000045,
#      'latitude': 45.786833,
#      'longitude': 3.149333,
#      'altitude': 331,
#      'libgeo': 'Clermont-Ferrand',
#      'codegeo': '63113',
#      'nom_epci': 'Clermont Auvergne Métropole',
#      'code_epci': '246300701',
#      'nom_dept': 'Puy-de-Dôme',
#      'code_dep': '63',
#      'nom_reg': 'Auvergne-Rhône-Alpes',
#      'code_reg': '84',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/c035048a105812966688063e7ed18f6e797fae37'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'c035048a105812966688063e7ed18f6e797fae37',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 334,
#     'fields': {'numer_sta': '78897',
#      'date': '2022-06-23T15:00:00+00:00',
#      'pmer': 101450,
#      'tend': 10.0,
#      'cod_tend': '2',
#      'dd': 150,
#      'ff': 5.8,
#      't': 303.75,
#      'td': 295.65,
#      'u': 62,
#      'vv': 50800.0,
#      'ww': None,
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': None,
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 101360.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 40.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': None,
#      'rafper': None,
#      'per': None,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': -0.1,
#      'rr24': -0.1,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': -61.516333, 'lat': 16.264},
#      'nom': 'LE RAIZET AERO',
#      'type_de_tendance_barometrique': 'En hausse',
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': 30.600000000000023,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': None,
#      'latitude': 16.264,
#      'longitude': -61.516333,
#      'altitude': 11,
#      'libgeo': 'Les Abymes',
#      'codegeo': '97101',
#      'nom_epci': 'CA Cap Excellence',
#      'code_epci': '200018653',
#      'nom_dept': 'Guadeloupe',
#      'code_dep': '971',
#      'nom_reg': 'Guadeloupe',
#      'code_reg': '01',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/0f54dab1a93e20582aade745456b6426030abce4'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '0f54dab1a93e20582aade745456b6426030abce4',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 664,
#     'fields': {'numer_sta': '07168',
#      'date': '2022-06-23T18:00:00+00:00',
#      'pmer': 100810,
#      'tend': -100.0,
#      'cod_tend': '8',
#      'dd': 30,
#      'ff': 2.3,
#      't': 297.05,
#      'td': 290.55,
#      'u': 67,
#      'vv': 20000.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
#      'n': 100.0,
#      'nbas': '8',
#      'hbas': 1750.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 99460.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': -110.0,
#      'tn12': 292.65,
#      'tn24': None,
#      'tx12': 300.85,
#      'tx24': None,
#      'tminsol': 293.25,
#      'sw': None,
#      'tw': None,
#      'raf10': 3.6,
#      'rafper': 4.4,
#      'per': -10.0,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.4,
#      'rr6': 0.4,
#      'rr12': 0.4,
#      'rr24': 0.4,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 1.0,
#      'ctype1': None,
#      'hnuage1': 1980.0,
#      'nnuage2': 8.0,
#      'ctype2': None,
#      'hnuage2': 4140.0,
#      'nnuage3': None,
#      'ctype3': '9',
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 4.02, 'lat': 48.324667},
#      'nom': 'TROYES-BARBEREY',
#      'type_de_tendance_barometrique': 'Stationnaire ou en hausse, puis en baisse, ou en baisse, puis en baisse plus rapide',
#      'temps_passe_1': None,
#      'temps_present': 'On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution',
#      'tc': 23.900000000000034,
#      'tn12c': 19.5,
#      'tn24c': None,
#      'tx12c': 27.700000000000045,
#      'tx24c': None,
#      'tminsolc': 20.100000000000023,
#      'latitude': 48.324667,
#      'longitude': 4.02,
#      'altitude': 112,
#      'libgeo': 'Barberey-Saint-Sulpice',
#      'codegeo': '10030',
#      'nom_epci': 'CA Troyes Champagne Métropole',
#      'code_epci': '200069250',
#      'nom_dept': 'Aube',
#      'code_dep': '10',
#      'nom_reg': 'Grand Est',
#      'code_reg': '44',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/774b3759e85d81be7b77f10a475b4a3a3a63d4aa'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '774b3759e85d81be7b77f10a475b4a3a3a63d4aa',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 667,
#     'fields': {'numer_sta': '07630',
#      'date': '2022-06-23T18:00:00+00:00',
#      'pmer': 101140,
#      'tend': 100.0,
#      'cod_tend': '3',
#      'dd': 140,
#      'ff': 2.2,
#      't': 293.75,
#      'td': 291.55,
#      'u': 87,
#      'vv': 19750.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
#      'n': 100.0,
#      'nbas': '8',
#      'hbas': 1750.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 99410.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 220.0,
#      'tn12': 292.45,
#      'tn24': None,
#      'tx12': 301.35,
#      'tx24': None,
#      'tminsol': 295.65,
#      'sw': None,
#      'tw': None,
#      'raf10': 3.5,
#      'rafper': 8.9,
#      'per': -10.0,
#      'etat_sol': '2',
#      'ht_neige': 0.0,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 2.0,
#      'rr3': 2.0,
#      'rr6': 2.0,
#      'rr12': 2.0,
#      'rr24': 2.0,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 2.0,
#      'ctype1': None,
#      'hnuage1': 1680.0,
#      'nnuage2': 3.0,
#      'ctype2': None,
#      'hnuage2': 2280.0,
#      'nnuage3': 6.0,
#      'ctype3': None,
#      'hnuage3': 2880.0,
#      'nnuage4': None,
#      'ctype4': '9',
#      'hnuage4': None,
#      'coordonnees': {'lon': 1.378833, 'lat': 43.621},
#      'nom': 'TOULOUSE-BLAGNAC',
#      'type_de_tendance_barometrique': 'En baisse ou stationnaire, puis en hausse, ou en hausse, puis en hausse plus rapide',
#      'temps_passe_1': None,
#      'temps_present': 'On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution',
#      'tc': 20.600000000000023,
#      'tn12c': 19.30000000000001,
#      'tn24c': None,
#      'tx12c': 28.200000000000045,
#      'tx24c': None,
#      'tminsolc': 22.5,
#      'latitude': 43.621,
#      'longitude': 1.378833,
#      'altitude': 151,
#      'libgeo': 'Blagnac',
#      'codegeo': '31069',
#      'nom_epci': 'Toulouse Métropole',
#      'code_epci': '243100518',
#      'nom_dept': 'Haute-Garonne',
#      'code_dep': '31',
#      'nom_reg': 'Occitanie',
#      'code_reg': '76',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/fa71cc6e39129a57d3584dd970ea1c547518aadd'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'fa71cc6e39129a57d3584dd970ea1c547518aadd',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 395,
#     'fields': {'numer_sta': '78897',
#      'date': '2022-06-23T18:00:00+00:00',
#      'pmer': 101290,
#      'tend': -160.0,
#      'cod_tend': '6',
#      'dd': 140,
#      'ff': 7.0,
#      't': 302.75,
#      'td': 295.95,
#      'u': 67,
#      'vv': 59940.0,
#      'ww': None,
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': None,
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 101200.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 40.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': None,
#      'rafper': None,
#      'per': None,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 0.0,
#      'rr24': -0.1,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': -61.516333, 'lat': 16.264},
#      'nom': 'LE RAIZET AERO',
#      'type_de_tendance_barometrique': 'En baisse, puis stationnaire, ou en baisse, puis en baisse plus lente',
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': 29.600000000000023,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': None,
#      'latitude': 16.264,
#      'longitude': -61.516333,
#      'altitude': 11,
#      'libgeo': 'Les Abymes',
#      'codegeo': '97101',
#      'nom_epci': 'CA Cap Excellence',
#      'code_epci': '200018653',
#      'nom_dept': 'Guadeloupe',
#      'code_dep': '971',
#      'nom_reg': 'Guadeloupe',
#      'code_reg': '01',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/f330fc173aaa6974de9a322a834c1f43e7e18f7c'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'f330fc173aaa6974de9a322a834c1f43e7e18f7c',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 326,
#     'fields': {'numer_sta': '89642',
#      'date': '2022-06-23T21:00:00+00:00',
#      'pmer': 97130,
#      'tend': -140.0,
#      'cod_tend': '6',
#      'dd': 140,
#      'ff': 17.0,
#      't': 259.25,
#      'td': 257.55,
#      'u': 86,
#      'vv': 2000.0,
#      'ww': None,
#      'w1': None,
#      'w2': None,
#      'n': 100.0,
#      'nbas': None,
#      'hbas': 1250.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 96580.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': None,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': 26.2,
#      'rafper': 28.3,
#      'per': -30.0,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': None,
#      'rr3': None,
#      'rr6': None,
#      'rr12': None,
#      'rr24': None,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 8.0,
#      'ctype1': '6',
#      'hnuage1': 1200.0,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 140.001, 'lat': -66.663167},
#      'nom': "DUMONT D'URVILLE",
#      'type_de_tendance_barometrique': 'En baisse, puis stationnaire, ou en baisse, puis en baisse plus lente',
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': -13.899999999999977,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': None,
#      'latitude': -66.663167,
#      'longitude': 140.001,
#      'altitude': 43,
#      'libgeo': None,
#      'codegeo': None,
#      'nom_epci': None,
#      'code_epci': None,
#      'nom_dept': None,
#      'code_dep': None,
#      'nom_reg': None,
#      'code_reg': None,
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/f09df4040afb000540a1c1b013794a0013c0f5be'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'f09df4040afb000540a1c1b013794a0013c0f5be',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 651,
#     'fields': {'numer_sta': '07020',
#      'date': '2022-06-24T00:00:00+00:00',
#      'pmer': 100900,
#      'tend': -20.0,
#      'cod_tend': '8',
#      'dd': 200,
#      'ff': 4.2,
#      't': 288.05,
#      'td': 286.75,
#      'u': 92,
#      'vv': 12000.0,
#      'ww': '1',
#      'w1': '0',
#      'w2': None,
#      'n': 25.0,
#      'nbas': '2',
#      'hbas': 2500.0,
#      'cl': '30',
#      'cm': '24',
#      'ch': '10',
#      'pres': 100790.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': -180.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': 6.0,
#      'rafper': 6.0,
#      'per': -10.0,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': -0.1,
#      'rr24': 2.0,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 2.0,
#      'ctype1': '3',
#      'hnuage1': 2500.0,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': -1.939833, 'lat': 49.725167},
#      'nom': 'PTE DE LA HAGUE',
#      'type_de_tendance_barometrique': 'Stationnaire ou en hausse, puis en baisse, ou en baisse, puis en baisse plus rapide',
#      'temps_passe_1': 'Nuages ne couvrant pas plus de la moitié du ciel pendant toute la période considérée',
#      'temps_present': 'Dans l’ensemble, nuages se dissipant ou devenant moins épais',
#      'tc': 14.900000000000034,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': None,
#      'latitude': 49.725167,
#      'longitude': -1.939833,
#      'altitude': 6,
#      'libgeo': 'La Hague',
#      'codegeo': '50041',
#      'nom_epci': 'CA du Cotentin',
#      'code_epci': '200067205',
#      'nom_dept': 'Manche',
#      'code_dep': '50',
#      'nom_reg': 'Normandie',
#      'code_reg': '28',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/58efc69c1edcab459aa3ae4bd2cdb9ba5aafa4d5'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '58efc69c1edcab459aa3ae4bd2cdb9ba5aafa4d5',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 620,
#     'fields': {'numer_sta': '07072',
#      'date': '2022-06-24T00:00:00+00:00',
#      'pmer': 100950,
#      'tend': 0.0,
#      'cod_tend': '0',
#      'dd': 180,
#      'ff': 2.6,
#      't': 291.25,
#      'td': 289.95,
#      'u': 92,
#      'vv': 3570.0,
#      'ww': '63',
#      'w1': None,
#      'w2': None,
#      'n': 100.0,
#      'nbas': '5',
#      'hbas': 1250.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 99840.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': -120.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': 290.45,
#      'sw': None,
#      'tw': None,
#      'raf10': 4.7,
#      'rafper': 8.2,
#      'per': -10.0,
#      'etat_sol': '2',
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 3.7,
#      'rr3': 6.1,
#      'rr6': 6.1,
#      'rr12': 6.1,
#      'rr24': 6.1,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 5.0,
#      'ctype1': None,
#      'hnuage1': 1140.0,
#      'nnuage2': 5.0,
#      'ctype2': None,
#      'hnuage2': 1350.0,
#      'nnuage3': 5.0,
#      'ctype3': None,
#      'hnuage3': 1680.0,
#      'nnuage4': None,
#      'ctype4': '9',
#      'hnuage4': None,
#      'coordonnees': {'lon': 4.155333, 'lat': 49.209667},
#      'nom': 'REIMS-PRUNAY',
#      'type_de_tendance_barometrique': 'En hausse, puis en baisse la pression atmosphérique est la même ou plus haute que trois heures auparavant',
#      'temps_passe_1': None,
#      'temps_present': 'Pluie, sans congélation, continue, modérée au moment de l’observation',
#      'tc': 18.100000000000023,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': 17.30000000000001,
#      'latitude': 49.209667,
#      'longitude': 4.155333,
#      'altitude': 95,
#      'libgeo': 'Prunay',
#      'codegeo': '51449',
#      'nom_epci': 'CU du Grand Reims',
#      'code_epci': '200067213',
#      'nom_dept': 'Marne',
#      'code_dep': '51',
#      'nom_reg': 'Grand Est',
#      'code_reg': '44',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/9f25730e49cff6879ecfcf3756595ac48e18319c'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '9f25730e49cff6879ecfcf3756595ac48e18319c',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 590,
#     'fields': {'numer_sta': '07168',
#      'date': '2022-06-24T00:00:00+00:00',
#      'pmer': 101090,
#      'tend': 0.0,
#      'cod_tend': '4',
#      'dd': 230,
#      'ff': 4.8,
#      't': 290.65,
#      'td': 288.65,
#      'u': 88,
#      'vv': 14930.0,
#      'ww': '61',
#      'w1': None,
#      'w2': None,
#      'n': 100.0,
#      'nbas': '8',
#      'hbas': 2250.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 99710.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': -10.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': 290.55,
#      'sw': None,
#      'tw': None,
#      'raf10': 6.9,
#      'rafper': 8.4,
#      'per': -10.0,
#      'etat_sol': '2',
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.6,
#      'rr3': 6.6,
#      'rr6': 17.5,
#      'rr12': 17.9,
#      'rr24': 17.9,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 5.0,
#      'ctype1': None,
#      'hnuage1': 2280.0,
#      'nnuage2': 8.0,
#      'ctype2': None,
#      'hnuage2': 2820.0,
#      'nnuage3': None,
#      'ctype3': '9',
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 4.02, 'lat': 48.324667},
#      'nom': 'TROYES-BARBEREY',
#      'type_de_tendance_barometrique': 'Stationnaire, la pression atmosphérique est la même que trois heures auparavant',
#      'temps_passe_1': None,
#      'temps_present': 'Pluie, sans congélation, continue, faible au moment de l’observation',
#      'tc': 17.5,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': 17.400000000000034,
#      'latitude': 48.324667,
#      'longitude': 4.02,
#      'altitude': 112,
#      'libgeo': 'Barberey-Saint-Sulpice',
#      'codegeo': '10030',
#      'nom_epci': 'CA Troyes Champagne Métropole',
#      'code_epci': '200069250',
#      'nom_dept': 'Aube',
#      'code_dep': '10',
#      'nom_reg': 'Grand Est',
#      'code_reg': '44',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/1364ac7cd9e86b1901a72ee7347656ca4b5db850'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '1364ac7cd9e86b1901a72ee7347656ca4b5db850',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 613,
#     'fields': {'numer_sta': '07335',
#      'date': '2022-06-24T00:00:00+00:00',
#      'pmer': 101230,
#      'tend': 10.0,
#      'cod_tend': '3',
#      'dd': 240,
#      'ff': 2.8,
#      't': 289.65,
#      'td': 288.15,
#      'u': 91,
#      'vv': 48210.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
#      'n': 100.0,
#      'nbas': '8',
#      'hbas': 1250.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 99820.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 10.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': 291.95,
#      'sw': None,
#      'tw': None,
#      'raf10': 4.2,
#      'rafper': 4.2,
#      'per': -10.0,
#      'etat_sol': '0',
#      'ht_neige': 0.0,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.2,
#      'rr6': 0.2,
#      'rr12': 0.4,
#      'rr24': 0.6,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 6.0,
#      'ctype1': None,
#      'hnuage1': 1200.0,
#      'nnuage2': 6.0,
#      'ctype2': None,
#      'hnuage2': 1500.0,
#      'nnuage3': 8.0,
#      'ctype3': None,
#      'hnuage3': 1800.0,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 0.314333, 'lat': 46.593833},
#      'nom': 'POITIERS-BIARD',
#      'type_de_tendance_barometrique': 'En baisse ou stationnaire, puis en hausse, ou en hausse, puis en hausse plus rapide',
#      'temps_passe_1': None,
#      'temps_present': 'On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution',
#      'tc': 16.5,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': 18.80000000000001,
#      'latitude': 46.593833,
#      'longitude': 0.314333,
#      'altitude': 123,
#      'libgeo': 'Poitiers',
#      'codegeo': '86194',
#      'nom_epci': 'CU du Grand Poitiers',
#      'code_epci': '200069854',
#      'nom_dept': 'Vienne',
#      'code_dep': '86',
#      'nom_reg': 'Nouvelle-Aquitaine',
#      'code_reg': '75',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/3c4476ca14cb7684672b19d60e8f2a542c2a910f'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '3c4476ca14cb7684672b19d60e8f2a542c2a910f',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 566,
#     'fields': {'numer_sta': '07643',
#      'date': '2022-06-24T00:00:00+00:00',
#      'pmer': 101260,
#      'tend': 70.0,
#      'cod_tend': '1',
#      'dd': 320,
#      'ff': 2.7,
#      't': 295.05,
#      'td': 293.65,
#      'u': 92,
#      'vv': 8790.0,
#      'ww': '61',
#      'w1': None,
#      'w2': None,
#      'n': 100.0,
#      'nbas': '8',
#      'hbas': 1750.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 101170.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 150.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': 293.85,
#      'sw': None,
#      'tw': None,
#      'raf10': 4.1,
#      'rafper': 7.7,
#      'per': -10.0,
#      'etat_sol': None,
#      'ht_neige': 0.0,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.2,
#      'rr3': 0.2,
#      'rr6': 2.4,
#      'rr12': 2.4,
#      'rr24': 2.4,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 5.0,
#      'ctype1': None,
#      'hnuage1': 1620.0,
#      'nnuage2': 5.0,
#      'ctype2': None,
#      'hnuage2': 2040.0,
#      'nnuage3': 8.0,
#      'ctype3': None,
#      'hnuage3': 3240.0,
#      'nnuage4': None,
#      'ctype4': '9',
#      'hnuage4': None,
#      'coordonnees': {'lon': 3.963167, 'lat': 43.577},
#      'nom': 'MONTPELLIER',
#      'type_de_tendance_barometrique': 'En hausse, puis stationnaire, ou en hausse, puis en hausse plus lente',
#      'temps_passe_1': None,
#      'temps_present': 'Pluie, sans congélation, continue, faible au moment de l’observation',
#      'tc': 21.900000000000034,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': 20.700000000000045,
#      'latitude': 43.577,
#      'longitude': 3.963167,
#      'altitude': 2,
#      'libgeo': 'Mauguio',
#      'codegeo': '34154',
#      'nom_epci': "CA du Pays de l'Or",
#      'code_epci': '243400470',
#      'nom_dept': 'Hérault',
#      'code_dep': '34',
#      'nom_reg': 'Occitanie',
#      'code_reg': '76',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/cd1caf2e5eba879ad94cd53b3efd0347dfc212fc'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'cd1caf2e5eba879ad94cd53b3efd0347dfc212fc',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 602,
#     'fields': {'numer_sta': '07027',
#      'date': '2022-06-24T03:00:00+00:00',
#      'pmer': 100840,
#      'tend': -130.0,
#      'cod_tend': '8',
#      'dd': 220,
#      'ff': 2.2,
#      't': 288.95,
#      'td': 287.45,
#      'u': 91,
#      'vv': 12360.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
# ...
#      'nom': 'CAP CEPET',
#      'type_de_tendance_barometrique': None,
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': None,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': None,
#      'latitude': 43.079333,
#      'longitude': 5.940833,
#      'altitude': 115,
#      'libgeo': 'Saint-Mandrier-sur-Mer',
#      'codegeo': '83153',
#      'nom_epci': 'Métropole Toulon-Provence-Méditerranée',
#      'code_epci': '248300543',
#      'nom_dept': 'Var',
#      'code_dep': '83',
#      'nom_reg': "Provence-Alpes-Côte d'Azur",
#      'code_reg': '93',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/d9ae6c7b1728f56106dddaa681ffa553f990acf0'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'd9ae6c7b1728f56106dddaa681ffa553f990acf0',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 339,
#     'fields': {'numer_sta': '61968',
#      'date': '2022-06-27T18:00:00+00:00',
#      'pmer': 101930,
#      'tend': 160.0,
#      'cod_tend': '1',
#      'dd': None,
#      'ff': None,
#      't': 298.85,
#      'td': 292.45,
#      'u': 68,
#      'vv': None,
#      'ww': None,
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': None,
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 101880.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 90.0,
#      'tn12': None,
#      'tn24': 292.45,
#      'tx12': None,
#      'tx24': 302.25,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': None,
#      'rafper': None,
#      'per': None,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 0.0,
#      'rr24': 0.0,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 47.289667, 'lat': -11.582667},
#      'nom': 'GLORIEUSES',
#      'type_de_tendance_barometrique': 'En hausse, puis stationnaire, ou en hausse, puis en hausse plus lente',
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': 25.700000000000045,
#      'tn12c': None,
#      'tn24c': 19.30000000000001,
#      'tx12c': None,
#      'tx24c': 29.100000000000023,
#      'tminsolc': None,
#      'latitude': -11.582667,
#      'longitude': 47.289667,
#      'altitude': 3,
#      'libgeo': None,
#      'codegeo': None,
#      'nom_epci': None,
#      'code_epci': None,
#      'nom_dept': None,
#      'code_dep': None,
#      'nom_reg': None,
#      'code_reg': None,
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/aab50532e31c0b5d04060a2fd84b9ceaf1e34c7f'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'aab50532e31c0b5d04060a2fd84b9ceaf1e34c7f',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 579,
#     'fields': {'numer_sta': '61980',
#      'date': '2022-06-27T21:00:00+00:00',
#      'pmer': 102340,
#      'tend': -50.0,
#      'cod_tend': '6',
#      'dd': 200,
#      'ff': 3.1,
#      't': 291.05,
#      'td': 288.85,
#      'u': 87,
#      'vv': 60000.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': '0',
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 102190.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 140.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': 4.2,
#      'rafper': 5.5,
#      'per': -10.0,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 0.0,
#      'rr24': 0.0,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 55.528667, 'lat': -20.8925},
#      'nom': 'GILLOT-AEROPORT',
#      'type_de_tendance_barometrique': 'En baisse, puis stationnaire, ou en baisse, puis en baisse plus lente',
#      'temps_passe_1': None,
#      'temps_present': 'On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution',
#      'tc': 17.900000000000034,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': None,
#      'latitude': -20.8925,
#      'longitude': 55.528667,
#      'altitude': 8,
#      'libgeo': 'Sainte-Marie',
#      'codegeo': '97418',
#      'nom_epci': 'CA Intercommunale du Nord de la Réunion (CINOR)',
#      'code_epci': '249740119',
#      'nom_dept': 'La Réunion',
#      'code_dep': '974',
#      'nom_reg': 'La Réunion',
#      'code_reg': '04',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/445b6a716331028b6081e9ad50ebba9d824d5d10'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '445b6a716331028b6081e9ad50ebba9d824d5d10',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 442,
#     'fields': {'numer_sta': '61998',
#      'date': '2022-06-28T00:00:00+00:00',
#      'pmer': 99070,
#      'tend': -300.0,
#      'cod_tend': '6',
#      'dd': 60,
#      'ff': 12.9,
#      't': 275.95,
#      'td': 273.95,
#      'u': 87,
#      'vv': None,
#      'ww': None,
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': None,
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 98700.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 130.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': None,
#      'rafper': 19.5,
#      'per': -10.0,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': None,
#      'rr6': 0.0,
#      'rr12': None,
#      'rr24': None,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 70.243333, 'lat': -49.352333},
#      'nom': 'KERGUELEN',
#      'type_de_tendance_barometrique': 'En baisse, puis stationnaire, ou en baisse, puis en baisse plus lente',
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': 2.8000000000000114,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': None,
#      'latitude': -49.352333,
#      'longitude': 70.243333,
#      'altitude': 29,
#      'libgeo': 'Archipel des Kerguelen',
#      'codegeo': '98412',
#      'nom_epci': None,
#      'code_epci': None,
#      'nom_dept': 'Terres australes et antarctiques françaises',
#      'code_dep': '984',
#      'nom_reg': 'Terres australes et antarctiques françaises',
#      'code_reg': '984',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/6dde04ad5f79d00332e5fdb4132aac95b67966cd'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '6dde04ad5f79d00332e5fdb4132aac95b67966cd',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 618,
#     'fields': {'numer_sta': '81405',
#      'date': '2022-06-28T00:00:00+00:00',
#      'pmer': 101180,
#      'tend': 270.0,
#      'cod_tend': '3',
#      'dd': 0,
#      'ff': 0.0,
#      't': 297.45,
#      'td': 296.45,
#      'u': 94,
#      'vv': 43850.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': '3',
#      'hbas': 3240.0,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 101090.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': -40.0,
#      'tn12': 304.15,
#      'tn24': None,
#      'tx12': 304.15,
#      'tx24': None,
#      'tminsol': 298.55,
#      'sw': None,
#      'tw': None,
#      'raf10': 1.1,
#      'rafper': 4.3,
#      'per': -10.0,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.6,
#      'rr3': 2.6,
#      'rr6': 2.6,
#      'rr12': 2.6,
#      'rr24': 17.8,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': 1.0,
#      'ctype1': None,
#      'hnuage1': 3240.0,
#      'nnuage2': 3.0,
#      'ctype2': None,
#      'hnuage2': 5040.0,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': -52.365333, 'lat': 4.822333},
#      'nom': 'CAYENNE-MATOURY',
#      'type_de_tendance_barometrique': 'En baisse ou stationnaire, puis en hausse, ou en hausse, puis en hausse plus rapide',
#      'temps_passe_1': None,
#      'temps_present': 'On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution',
#      'tc': 24.30000000000001,
#      'tn12c': 31.0,
#      'tn24c': None,
#      'tx12c': 31.0,
#      'tx24c': None,
#      'tminsolc': 25.400000000000034,
#      'latitude': 4.822333,
#      'longitude': -52.365333,
#      'altitude': 4,
#      'libgeo': 'Matoury',
#      'codegeo': '97307',
#      'nom_epci': 'CA du Centre Littoral',
#      'code_epci': '249730045',
#      'nom_dept': 'Guyane',
#      'code_dep': '973',
#      'nom_reg': 'Guyane',
#      'code_reg': '03',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/89fe02b0ee6427ec1fdd07aa1691fe80cc2f5ca8'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': '89fe02b0ee6427ec1fdd07aa1691fe80cc2f5ca8',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 577,
#     'fields': {'numer_sta': '07190',
#      'date': '2022-06-28T03:00:00+00:00',
#      'pmer': 102270,
#      'tend': 10.0,
#      'cod_tend': '3',
#      'dd': 310,
#      'ff': 1.4,
#      't': 285.65,
#      'td': 285.05,
#      'u': 96,
#      'vv': 32130.0,
#      'ww': '0',
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': '0',
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 100450.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 750.0,
#      'tn12': None,
#      'tn24': None,
#      'tx12': None,
#      'tx24': None,
#      'tminsol': 284.35,
#      'sw': None,
#      'tw': None,
#      'raf10': 2.1,
#      'rafper': 2.1,
#      'per': -10.0,
#      'etat_sol': '0',
#      'ht_neige': 0.0,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 0.0,
#      'rr24': 3.6,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': 7.640333, 'lat': 48.5495},
#      'nom': 'STRASBOURG-ENTZHEIM',
#      'type_de_tendance_barometrique': 'En baisse ou stationnaire, puis en hausse, ou en hausse, puis en hausse plus rapide',
#      'temps_passe_1': None,
#      'temps_present': 'On n’a pas observé d’évolution des nuages ou on n’a pas pu suivre cette évolution',
#      'tc': 12.5,
#      'tn12c': None,
#      'tn24c': None,
#      'tx12c': None,
#      'tx24c': None,
#      'tminsolc': 11.200000000000045,
#      'latitude': 48.5495,
#      'longitude': 7.640333,
#      'altitude': 150,
#      'libgeo': 'Holtzheim',
#      'codegeo': '67212',
#      'nom_epci': 'Eurométropole de Strasbourg',
#      'code_epci': '246700488',
#      'nom_dept': 'Bas-Rhin',
#      'code_dep': '67',
#      'nom_reg': 'Grand Est',
#      'code_reg': '44',
#      'mois_de_l_annee': 6}}},
#   {'links': [{'rel': 'self',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm/records/cf78afa6f318498e9142bcdd2604e76375ed8058'},
#     {'rel': 'datasets',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets'},
#     {'rel': 'dataset',
#      'href': 'https://public.opendatasoft.com/api/explore/v2.0/catalog/datasets/donnees-synop-essentielles-omm'}],
#    'record': {'id': 'cf78afa6f318498e9142bcdd2604e76375ed8058',
#     'timestamp': '2022-06-30T21:00:00Z',
#     'size': 443,
#     'fields': {'numer_sta': '78890',
#      'date': '2022-06-28T03:00:00+00:00',
#      'pmer': 101700,
#      'tend': 60.0,
#      'cod_tend': '1',
#      'dd': 60,
#      'ff': 11.1,
#      't': 298.55,
#      'td': 294.05,
#      'u': 76,
#      'vv': None,
#      'ww': None,
#      'w1': None,
#      'w2': None,
#      'n': None,
#      'nbas': None,
#      'hbas': None,
#      'cl': None,
#      'cm': None,
#      'ch': None,
#      'pres': 101380.0,
#      'niv_bar': None,
#      'geop': None,
#      'tend24': 20.0,
#      'tn12': None,
#      'tn24': 295.45,
#      'tx12': None,
#      'tx24': 304.45,
#      'tminsol': None,
#      'sw': None,
#      'tw': None,
#      'raf10': None,
#      'rafper': None,
#      'per': None,
#      'etat_sol': None,
#      'ht_neige': None,
#      'ssfrai': None,
#      'perssfrai': None,
#      'rr1': 0.0,
#      'rr3': 0.0,
#      'rr6': 0.0,
#      'rr12': 0.0,
#      'rr24': 0.0,
#      'phenspe1': None,
#      'phenspe2': None,
#      'phenspe3': None,
#      'phenspe4': None,
#      'nnuage1': None,
#      'ctype1': None,
#      'hnuage1': None,
#      'nnuage2': None,
#      'ctype2': None,
#      'hnuage2': None,
#      'nnuage3': None,
#      'ctype3': None,
#      'hnuage3': None,
#      'nnuage4': None,
#      'ctype4': None,
#      'hnuage4': None,
#      'coordonnees': {'lon': -61.004, 'lat': 16.335},
#      'nom': 'LA DESIRADE METEO',
#      'type_de_tendance_barometrique': 'En hausse, puis stationnaire, ou en hausse, puis en hausse plus lente',
#      'temps_passe_1': None,
#      'temps_present': None,
#      'tc': 25.400000000000034,
#      'tn12c': None,
#      'tn24c': 22.30000000000001,
#      'tx12c': None,
#      'tx24c': 31.30000000000001,
#      'tminsolc': None,
#      'latitude': 16.335,
#      'longitude': -61.004,
#      'altitude': 27,
#      'libgeo': 'La Désirade',
#      'codegeo': '97110',
#      'nom_epci': 'CA La Riviera du Levant',
#      'code_epci': '200041507',
#      'nom_dept': 'Guadeloupe',
#      'code_dep': '971',
#      'nom_reg': 'Guadeloupe',
#      'code_reg': '01',
#      'mois_de_l_annee': 6}}}]}

# %%
df.head(5)
# Out:
#    ID OMM station                       Date  Pression au niveau mer  \
# 0            7558  2010-01-05T10:00:00+01:00                100280.0
# 1           61976  2010-01-05T10:00:00+01:00                100990.0
# 2            7027  2010-01-05T13:00:00+01:00                100720.0
# 3            7110  2010-01-05T13:00:00+01:00                100750.0
# 4            7591  2010-01-05T13:00:00+01:00                     NaN
#
#    Variation de pression en 3 heures  Type de tendance barométrique  \
# 0                              -50.0                            5.0
# 1                                NaN                            NaN
# 2                             -190.0                            8.0
# 3                             -230.0                            8.0
# 4                                NaN                            NaN
#
#    Direction du vent moyen 10 mn  Vitesse du vent moyen 10 mn  Température  \
# 0                          260.0                          1.5       275.75
# 1                            NaN                          NaN       305.45
# 2                          200.0                          3.6       273.65
# 3                          210.0                          4.1       276.95
# 4                            NaN                          NaN       274.45
#
#    Point de rosée  Humidité  ...  Altitude  communes (name)  communes (code)  \
# 0          275.75     100.0  ...       712           Millau            12145
# 1          299.05      69.0  ...         7              NaN              NaN
# 2          271.75      87.0  ...        67        Carpiquet            14137
# 3          272.55      73.0  ...        94         Guipavas            29075
# 4          269.05      67.0  ...       871           Embrun            05046
#
#                    EPCI (name)  EPCI (code)  department (name)  \
# 0  CC de Millau Grands Causses  241200567.0            Aveyron
# 1                          NaN          NaN                NaN
# 2               CU Caen la Mer  200065597.0           Calvados
# 3              Brest Métropole  242900314.0          Finistère
# 4              CC Serre-Ponçon  200067742.0       Hautes-Alpes
#
#    department (code)               region (name)  region (code)  \
# 0                 12                   Occitanie           76.0
# 1                NaN                         NaN            NaN
# 2                 14                   Normandie           28.0
# 3                 29                    Bretagne           53.0
# 4                 05  Provence-Alpes-Côte d'Azur           93.0
#
#    mois_de_l_annee
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
#
# [5 rows x 82 columns]
